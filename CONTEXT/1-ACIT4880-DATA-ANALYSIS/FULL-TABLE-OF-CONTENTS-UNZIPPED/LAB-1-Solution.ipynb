# %% [markdown]
# # Lab 1

# %% [markdown]
# #### Each numbered item will be a new cell. Press SHIFT+ENTER to run a cell and create a new cell below. With the cell selected, press ESCAPE to go into command mode. Use shortcuts M and Y to change cells to markdown and code, respectively.

# %% [markdown]
# ### 1. Create a new notebook, name it, and add two headings below with Heading Level 1 and 4.

# %% [markdown]
# # Heading Level 1
#
# ##### Heading Level 4

# %% [markdown]
# ### 2. Duplicate the following paragraph. Pay attention to the bold, italic, blockquotes, numbered lists, and unordered list items.

# %% [markdown]
# I just love **bold_text**, *italic_text* and ***bold_italic_text***. Just look at the following blockquotes:
# > This blockquote is very helpful
# >
# >>Alongside this sub blockquote
#
# I also like the folloing numbered list items:
# 1. List 1
# 2. List 2
#     a. Nested list
#     - With an unordered sublist
#
# Let's end this with three horizontal lines:
#
# ***
#
# ---
#
# ___

# %% [markdown]
# ### 3. Create this link "https://www.dataquest.io/blog/jupyter-notebook-tutorial/ "as clickable with this title "How to Use Jupyter Notebook"

# %% [markdown]
# This is a [tutorial link](https://www.dataquest.io/blog/jupyter-notebook-tutorial/ "How to Use Jupyter Notebook")

# %% [markdown]
# ### 4. display the following image from this link: https://kiran-parte.github.io/aiforall/assets/images/blog/jupyter.jpg

# %% [markdown]
# ![image](https://kiran-parte.github.io/aiforall/assets/images/blog/jupyter.jpg)

# %% [markdown]
# ### 5. Create the following table

# %% [markdown]
# | Column 1 | Column 2 | Column 3 |
# |:--------:|:--------:|:--------:|
# |  Row 1   |  Row 1   |  Row 1   |
# |  Row 2   |  Row 2   |  Row 2   |
# |  Row 3   |  Row 3   |  Row 3   |

# %% [markdown]
# ### 6. Write the followng formulas in a new cell (markdown cell):

# %% [markdown]
# #### Relevant formulas
#
# - square area: $s = (2 r)^2$
# - circle area: $c = \pi r^2$
# - $c/s = (\pi r^2) / (4 r^2) = \pi / 4$
# - $\pi = 4 * c/s$

# %% [markdown]
# ### 7. Embed the following python code

# %% [markdown]
# Python code for addition
# ```python
# a = 10
# b = 10
# c = a+b
# print(C)
# ```

# %% [markdown]
# ### 8. Generate a square shape like the circle shape below using Scalable Vector Graphics in cell magic

# %%
# %%SVG
#
# <svg weight="100" height="100">
#     <circle cx="50" cy="50" r="40" stroke="blue" stroke-weight="4" fill="brown"/>
# </svg>

# %% [markdown]
# ### 9. Show how much time this program spent in each function with the cell magic command of pyhton code profiler
#
# ```python
# def function():
#     i = 1000
#     sum = 0
#     while i > 0 :
#         i = i - 1
#         sum = sum + i
#     print(sum)
# ```

# %%
# %%prun
print()
def function():
    i = 1000
    sum = 0
    while i > 0 :
        i = i - 1
        sum = sum + i
    print(sum)
function()
# Out:
# 499500

# %%
# %prun function()
# Out:
# 499500
