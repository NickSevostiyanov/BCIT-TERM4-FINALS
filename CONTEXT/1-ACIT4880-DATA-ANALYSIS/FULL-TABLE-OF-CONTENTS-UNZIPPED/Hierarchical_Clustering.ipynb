# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
import seaborn as sns
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Display the first few rows of the dataset
print("Dataset Preview:")
print(df.head())

# Extract features
features = df.iloc[:, 0:3].values

# Standardize the features
scaler = StandardScaler()
features_standardized = scaler.fit_transform(features)
# Out:
# Dataset Preview:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(features_standardized, method = 'ward'))
plt.title('iRis')
plt.xlabel('Sepal leng')
plt.ylabel('Sepal width')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 3, metric = 'euclidean', linkage = 'complete')
y_hc = hc.fit_predict(features_standardized)
hc.get_params()
# Out:
# {'affinity': 'deprecated',
#  'compute_distances': False,
#  'compute_full_tree': 'auto',
#  'connectivity': None,
#  'distance_threshold': None,
#  'linkage': 'complete',
#  'memory': None,
#  'metric': 'euclidean',
#  'n_clusters': 3}

# %%
# Add a new column to the dataframe for the cluster labels
df['Cluster'] = y_hc

# Visualize the clustered data
plt.figure(figsize=(8, 4))
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', hue='Cluster', data=df, palette='viridis')
plt.title('Hierarchical Clustering Results')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# Display the first few rows of the dataset with cluster labels
print("\nDataset with Cluster Labels:")
print(df.head())
# Out:
# Dataset with Cluster Labels:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Cluster
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# Q1. Perform Hierarchical Clustering on the "Mall_Customers.csv" dataset. Repaet the steps shown in the example above.
#
# Q2. Instaed of Standardizing the iris dataset, normalize the input features.
#
# Q3. Perform hierarchical clustering on the iris dataset using a different metric and linkage method than the example above.
#
# Q4. Determine the optimal number of clusters by elbow method.
#
# Q5. Assign each data point to its respective cluster.
#
# Q6. Visualize the clustered data using a scatter plot with different colors for each cluster.
