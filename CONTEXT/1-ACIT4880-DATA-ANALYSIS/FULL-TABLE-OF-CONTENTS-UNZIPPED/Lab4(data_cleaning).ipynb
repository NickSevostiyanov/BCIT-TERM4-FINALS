# %% [markdown]
# # Data Cleaning and Feature Engineering Lab

# %% [markdown]
# 1. Import the Required Libraries

# %% [markdown]
# 2. Load the Dataset
#
# > Load customer_data.csv into a Pandas DataFrame and inspect the first few rows to understand the structure.

# %% [markdown]
# 3. Standardize Column Names:
#
# > Convert all column names to lowercase and replace spaces with underscores (do the opposite to it).

# %% [markdown]
# 4. Remove Duplicates:
#
# > Check for duplicate rows and remove them.

# %% [markdown]
# 5. Fix Age Values:
#
# > Identify outliers in the age column (e.g., values < 0 or > 120) and replace them with NaN.

# %% [markdown]
# 6. Validate Email Addresses:
#
# > Write a function to check if an email address has a valid format (e.g., contains "@" and "."). Flag invalid emails for further review.

# %% [markdown]
# 7. Clean the Region Column:
#
# > Standardize region names by correcting common misspellings (e.g., "Norrth" to "North").

# %% [markdown]
# 8. Handle Purchase Data:
#
# > Identify negative or nonsensical values in the purchases column and replace them with 0.

# %% [markdown]
# 9. Normalize Membership Levels:
#
# > Ensure membership levels (Gold, Silver, Bronze) are consistent in spelling and case.

# %% [markdown]
# 10. Feature Engineering Tasks
#
# > Extract First and Last Names:
#
# >> Split the name column into first_name and last_name.
#
# > Calculate Membership Duration:
#
# >>Create a new column membership_duration that calculates the number of days since signup_date.

# %% [markdown]
# 11. Inconsistent Signup Dates:
#
# > Some signup_date entries might have incorrect formats or invalid dates (e.g., "20231301"). Correct these or flag them.

# %% [markdown]
# 12. Missing Regions:
#
# > Assign "Unknown" to entries where the region column is blank.

# %% [markdown]
# 13. Customers with No Purchases:
#
# > Add a new column is_active that flags customers as True if they have made purchases, otherwise False.

# %% [markdown]
# 14. At the end of your cleaning process, generate a summary report that includes:
#
# >Total number of rows before and after cleaning.
#
# >Number of rows affected by each cleaning operation.
#
# >Top 5 regions by the number of customers.

# %% [markdown]
# 15. Save cleaned data @ cleaned_customer_data.csv
